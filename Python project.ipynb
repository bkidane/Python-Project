# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy.random as np
import sys
import sqlite3 
import matplotlib

# %matplotlib inline

# %% [markdown]
# How do power page views or content views vary by retail account? Look at top 5 retailers over the last 3 years.

# %%
df = pd.read_excel("Python-Project/Revised_webcollage_report.xlsx", 0, index_col='Month')
df
# Out:
#               Site Name  Power Page Views  Mini-Site Clicks  Content Views  \
# Month
# 2016-10        Best Buy              1115              6556           7671
# 2016-10  BrandsMart USA               874                 0            874
# 2016-10           Lowes            266307                89         266396
# 2016-10      PC Richard             21609               340          21949
# 2016-10         Wayfair                 3                 0              3
# 2016-11        Best Buy              1897             15199          17096
# 2016-11  BrandsMart USA               975                 0            975
# 2016-11           Lowes            428081               333         428414
# 2016-11      PC Richard             35659               532          36191
# 2016-11         Wayfair                12                 0             12
# 2016-12        Best Buy              1154              7727           8881
# ...

# %% [markdown]
# Use the groupby function to sort by retailer

# %%
df = pd.read_excel('Python-Project/Revised_webcollage_report.xlsx', 0, index_col='Month')
df.groupby(['Site Name']).sum()
# Out:
#                 Power Page Views  Mini-Site Clicks  Content Views  \
# Site Name
# Best Buy                  333507            175827         509334
# BrandsMart USA             42536                 0          42536
# Lowes                   26176819             38554       26215373
# PC Richard                989864             18543        1008407
# Wayfair                      326                 0            326
#
#                  Total Sales
# Site Name
# Best Buy        1.374620e+07
# BrandsMart USA  5.105536e+05
# Lowes           2.882875e+08
# PC Richard      1.340359e+07
# Wayfair         1.709416e+02

# %%
df.to_sql('SQL_database', sqlite3.connect('Revised_webcollage_report.db'), if_exists='replace')
# Out:
# C:\Program Files\Anaconda\lib\site-packages\pandas\core\generic.py:2127: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype)

# %% [markdown]
# Create a SQL database

# %%
sql_df = pd.read_sql_query("SELECT * FROM SQL_database", sqlite3.connect('Revised_webcollage_report.db'));
sql_df
# Out:
#        Month       Site Name  Power Page Views  Mini-Site Clicks  \
# 0    2016-10        Best Buy              1115              6556
# 1    2016-10  BrandsMart USA               874                 0
# 2    2016-10           Lowes            266307                89
# 3    2016-10      PC Richard             21609               340
# 4    2016-10         Wayfair                 3                 0
# 5    2016-11        Best Buy              1897             15199
# 6    2016-11  BrandsMart USA               975                 0
# 7    2016-11           Lowes            428081               333
# 8    2016-11      PC Richard             35659               532
# 9    2016-11         Wayfair                12                 0
# 10   2016-12        Best Buy              1154              7727
# 11   2016-12  BrandsMart USA               862                 0
# 12   2016-12           Lowes            291130               251
# ...

# %% [markdown]
# Run a similar groupby function using a SQL query

# %%
sql_df = pd.read_sql_query("SELECT [Site Name], count(*) FROM SQL_database GROUP BY [Site Name]", sqlite3.connect('Revised_webcollage_report.db'));
sql_df
# Out:
#         Site Name  count(*)
# 0        Best Buy        24
# 1  BrandsMart USA        24
# 2           Lowes        24
# 3      PC Richard        24
# 4         Wayfair        24

# %%
df = pd.read_excel('Python-Project/Revised_webcollage_report.xlsx', 0, index_col='Month')
df.index
# Out:
# Index(['2016-10', '2016-10', '2016-10', '2016-10', '2016-10', '2016-11',
#        '2016-11', '2016-11', '2016-11', '2016-11',
#        ...
#        '2018-08', '2018-08', '2018-08', '2018-08', '2018-08', '2018-09',
#        '2018-09', '2018-09', '2018-09', '2018-09'],
#       dtype='object', name='Month', length=120)

# %%
df = pd.read_excel('Python-Project/Revised_webcollage_report.xlsx', 0, index_col='Month')
df.columns
# Out:
# Index(['Site Name', 'Power Page Views', 'Mini-Site Clicks', 'Content Views',
#        'Total Sales'],
#       dtype='object')

# %% [markdown]
# Clean up the data, only look at revelant columns

# %%
df = pd.read_excel('Python-Project/Revised_webcollage_report.xlsx', 0, index_col='Month')
df[['Site Name','Power Page Views', 'Mini-Site Clicks','Content Views','Total Sales']]
# Out:
#               Site Name  Power Page Views  Mini-Site Clicks  Content Views  \
# Month
# 2016-10        Best Buy              1115              6556           7671
# 2016-10  BrandsMart USA               874                 0            874
# 2016-10           Lowes            266307                89         266396
# 2016-10      PC Richard             21609               340          21949
# 2016-10         Wayfair                 3                 0              3
# 2016-11        Best Buy              1897             15199          17096
# 2016-11  BrandsMart USA               975                 0            975
# 2016-11           Lowes            428081               333         428414
# 2016-11      PC Richard             35659               532          36191
# 2016-11         Wayfair                12                 0             12
# 2016-12        Best Buy              1154              7727           8881
# ...

# %%
df.round(2)
# Out:
#               Site Name  Power Page Views  Mini-Site Clicks  Content Views  \
# Month
# 2016-10        Best Buy              1115              6556           7671
# 2016-10  BrandsMart USA               874                 0            874
# 2016-10           Lowes            266307                89         266396
# 2016-10      PC Richard             21609               340          21949
# 2016-10         Wayfair                 3                 0              3
# 2016-11        Best Buy              1897             15199          17096
# 2016-11  BrandsMart USA               975                 0            975
# 2016-11           Lowes            428081               333         428414
# 2016-11      PC Richard             35659               532          36191
# 2016-11         Wayfair                12                 0             12
# 2016-12        Best Buy              1154              7727           8881
# ...

# %% [markdown]
# Round the data so that it only shows up to 2 decimal points.

# %%
df = pd.read_excel('Python-Project/Revised_webcollage_report.xlsx', 0, index_col='Month')
nf = df.round(2)
nf[['Site Name','Power Page Views', 'Mini-Site Clicks','Content Views', 'Total Sales']]
# Out:
#               Site Name  Power Page Views  Mini-Site Clicks  Content Views  \
# Month
# 2016-10        Best Buy              1115              6556           7671
# 2016-10  BrandsMart USA               874                 0            874
# 2016-10           Lowes            266307                89         266396
# 2016-10      PC Richard             21609               340          21949
# 2016-10         Wayfair                 3                 0              3
# 2016-11        Best Buy              1897             15199          17096
# 2016-11  BrandsMart USA               975                 0            975
# 2016-11           Lowes            428081               333         428414
# 2016-11      PC Richard             35659               532          36191
# 2016-11         Wayfair                12                 0             12
# 2016-12        Best Buy              1154              7727           8881
# ...

# %% [markdown]
# Plot the data in a line chart; test with 3 values.

# %%
df = pd.read_excel('Python-Project/Revised_webcollage_report.xlsx', 0, index_col='Month')
nf = df.round(2)
nf[['Site Name','Power Page Views', 'Mini-Site Clicks','Content Views', 'Total Sales']]
df = pd.DataFrame([[1115, 7671, 527865.37], [874, 875, 7402.68], [266307, 89, 2103593]], index=pd.date_range('2016-10', periods=3), columns=['Power Page Views', 'Content Views', 'Total Sales']).cumsum()

plt.figure(); df.plot(); plt.legend(loc='best')

# %% [markdown]
# Need to clean up the data: combine the months so it reads by year vs by Month.

# %%
df = pd.read_excel('Python-Project/Revised_webcollage_report.xlsx', 0)
nf = df.round(2)
df['Year'] = df['Month'].str.slice(0,4)
df.groupby(['Site Name', 'Year'], as_index=False).sum()
# Out:
#          Site Name  Year  Power Page Views  Mini-Site Clicks  Content Views  \
# 0         Best Buy  2016              4166             29482          33648
# 1         Best Buy  2017             90334             94068         184402
# 2         Best Buy  2018            239007             52277         291284
# 3   BrandsMart USA  2016              2711                 0           2711
# 4   BrandsMart USA  2017              6185                 0           6185
# 5   BrandsMart USA  2018             33640                 0          33640
# 6            Lowes  2016            985518               673         986191
# 7            Lowes  2017           9652291             19368        9671659
# 8            Lowes  2018          15539010             18513       15557523
# 9       PC Richard  2016             76855              1149          78004
# 10      PC Richard  2017            449356             17386         466742
# ...

# %% [markdown]
# Plot all the data in a line graph; name the graph.

# %%
df.columns
# Out:
# Index(['Month', 'Site Name', 'Power Page Views', 'Mini-Site Clicks',
#        'Content Views', 'Total Sales', 'Year'],
#       dtype='object')

# %%
df = pd.read_excel('Python-Project/Revised_webcollage_report.xlsx', 0)
df['Year'] = df['Month'].str.slice(0,4)
data = {'Best Buy': [4166, 90334, 239007], 'BrandsMart USA': [2711, 6185, 33640], 'Lowes': [985518, 9652291, 15539010], 'PC Richard': [76855, 449356, 463653], 'Wayfair': [40, 164, 122]}
df = pd.DataFrame([[4166, 2711, 985518, 76855, 40],
                   [90334, 6185, 9652291, 76855, 164],
                   [239007, 33640, 15539010, 463653, 122]],
                  index=pd.date_range('2016', periods=3, freq='y'), columns=['Best Buy','BrandsMart USA','Lowes', 'PC Richard', 'Wayfair']).cumsum()

plt.figure(); df.plot(); plt.legend(loc='best'); plt.title("Retailers x Power Page Views", loc='right'), plt.xlabel("Year"), plt.ylabel("Power Page Views")
# Out:
# (Text(1,1,'Retailers x Power Page Views'),
#  Text(0.5,0,'Year'),
#  Text(0,0.5,'Power Page Views'))

# %% [markdown]
# Conclusion: Lowes far exceeds the other 4 retailers in power page views over the last 3 years.
